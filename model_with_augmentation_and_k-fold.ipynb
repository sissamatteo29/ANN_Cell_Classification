# %% [markdown]
# # Artificial Neural Networks and Deep Learning
#
#
#
#
#
# ---
#
#
#
#
#
# # Homework 1

# %% [markdown]
# ## ⚙️ Import Libraries

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.gridspec as gridspec

seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## ⏳ Load the Data

# %%
# Load Data
#data = np.load('training_set.npz')
data = np.load('/kaggle/input/training-set/training_set.npz')

data
X = data['images']
y = data['labels']

np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7], dtype=uint8),
#  array([1052, 2381, 1285, 2226, 1049, 1393, 2530, 1843]))

# %%
# Labels dictionary
labels_dict = {
    0: 'Basophil',
    1: 'Eosinophil',
    2: 'Erythroblast',
    3: 'Immature granulocytes',
    4: 'Lymphocyte',
    5: 'Monocyte',
    6: 'Neutrophil',
    7: 'Platelet'
}

# %%
class_count = {}
for i in labels_dict:
    class_count[i] = np.unique(y, return_counts=True)[1][i]

class_count
# Out:
# {0: 1052, 1: 2381, 2: 1285, 3: 2226, 4: 1049, 5: 1393, 6: 2530, 7: 1843}

# %%
# see image augmentation section to fix unbalanced classes

# %%
fig, axs = plt.subplots(3, 3, figsize=(10, 10))
axs = axs.reshape((-1,))
for i in range(9):
    axs[i].imshow(X[i])
    axs[i].set_title(f'Class: {labels_dict[y[i][0]]} {y[i]}')
    axs[i].axis('off')

# %%
# Normalize data to the range [0, 1]
X = (X / 255).astype('float32')

# %% [markdown]
# ## Image Augmentation

# %%
print(labels_dict)
np.unique(y, return_counts=True)
# Out:
# {0: 'Basophil', 1: 'Eosinophil', 2: 'Erythroblast', 3: 'Immature granulocytes', 4: 'Lymphocyte', 5: 'Monocyte', 6: 'Neutrophil', 7: 'Platelet'}
# (array([0, 1, 2, 3, 4, 5, 6, 7], dtype=uint8),
#  array([1052, 2381, 1285, 2226, 1049, 1393, 2530, 1843]))

# %% [markdown]
# class `6: 'Neutrophil'` has the most images with 2530 samples. Have to augment to level all other classes to this one

# %%
# Define a sequential model for image augmentation
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.2,0.2),
    tfkl.RandomRotation(0.2),
    tfkl.RandomZoom(0.2),
    tfkl.RandomBrightness(0.5, value_range=(0,1)),
    tfkl.RandomContrast(0.75),
], name='Augmentation')

# Set up the figure and grid layout for displaying images
fig, axs = plt.subplots(1, 4, figsize=(10, 10))

img = X[0] # Select the first image from the dataset for example

# Display the original image
axs[0].imshow(img)
axs[0].axis('off')
axs[0].set_title('Original Image')

# Apply augmentation and display the first augmented image
augmented_img = np.clip(augmentation(img), 0., 1.)
axs[1].imshow(augmented_img)
axs[1].axis('off')
axs[1].set_title('Augmented Image 1')

# Apply augmentation and display the second augmented image
augmented_img = np.clip(augmentation(img), 0., 1.)
axs[2].imshow(augmented_img)
axs[2].axis('off')
axs[2].set_title('Augmented Image 2')

# Apply augmentation and display the third augmented image
augmented_img = np.clip(augmentation(img), 0., 1.)
axs[3].imshow(augmented_img)
axs[3].axis('off')
axs[3].set_title('Augmented Image 3')

plt.show()

# %% [markdown]
# This is the augmentation layer that will be used for all classes to reach 2600 samples

# %%
new_x = []
new_y = []
# Sweep for every class
for clas in class_count:
    print(f'Class: {clas}')
    # Filter images of current class
    class_images = X[y.flatten() == clas]

    while class_count[clas] < 2600:
        # Select a random image from the current class
        random_index = np.random.randint(0, class_images.shape[0])
        original_img = class_images[random_index]

        # Apply augmentation layer
        augmented_img = np.clip(augmentation(original_img), 0., 1.)

        # Add new image and its label to data
        new_x.append(augmented_img)
        new_y.append(clas)

        class_count[clas] += 1

# Concatenate the augmented data into the whole data
new_x = np.array(new_x)
new_y = np.array(new_y).reshape(-1, 1)

X = np.concatenate([X, new_x], axis=0)
y = np.concatenate([y, new_y], axis=0)
# Out:
# Class: 0
# Class: 1
# Class: 2
# Class: 3
# Class: 4
# Class: 5
# Class: 6
# Class: 7

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  array([2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600]))

# %% [markdown]
# ## 🔄 Process Data

# %%
# Convert labels to categorical format using one-hot encoding
y = tfk.utils.to_categorical(y)

# %%
test_val_size = 0.05 # parameter to tune

# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=test_val_size, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=len(X_test), stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (18720, 96, 96, 3), y_train shape: (18720, 8)
# X_val shape: (1040, 96, 96, 3), y_val shape: (1040, 8)
# X_test shape: (1040, 96, 96, 3), y_test shape: (1040, 8)

# %% [markdown]
# ## 🧮 Define Network Parameters

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8

# %%
# Number of training epochs
epochs = 100 # parameter to tune

# Batch size for training
batch_size = 32 # parameter to tune

# Learning rate: step size for updating the model's weights
learning_rate = 0.001 # parameter to tune

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
print("Learning Rate:", learning_rate)
# Out:
# Epochs: 100
# Batch Size: 32
# Learning Rate: 0.001

# %% [markdown]
# ## 🛠️ Build the Model

# %%
# Todo: Add augmentation
# # Define a data augmentation pipeline with random flip, brightness, and translation
# augmentation = tf.keras.Sequential([
#     tfkl.RandomFlip("horizontal"),
#     tfkl.RandomBrightness(0.2, value_range=(0,1)),
#     tfkl.RandomTranslation(0.2,0.2),
# ], name='preprocessing')

# # Build the model with specified input and output shapes
# model = build_model(augmentation=augmentation)

# # Display a summary of the model architecture
# model.summary(expand_nested=True, show_trainable=True)

# # Plot the model architecture
# tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %%
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate,
    augmentation=None,
    seed=seed
):

    tf.random.set_seed(seed)

    # Build the neural network layer by layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv2D(filters=32, kernel_size=3, padding='same', name='conv1')(inputs)
    x = tfkl.Activation('relu', name='act1')(x)
    x = tfkl.MaxPooling2D(pool_size=2, name='mp1')(x)

    x = tfkl.Conv2D(filters=64, kernel_size=3, padding='same', name='conv2')(x)
    x = tfkl.Activation('relu', name='act2')(x)
    x = tfkl.MaxPooling2D(pool_size=2, name='mp2')(x)

    x = tfkl.Flatten(name='flatten')(x)
    x = tfkl.Dense(units=output_shape, name='dense')(x)
    outputs = tfkl.Activation('softmax', name='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=inputs, outputs=outputs, name='CNN')

    # Compile the model
    loss = tfk.losses.CategoricalCrossentropy()
    optimizer = tfk.optimizers.Adam(learning_rate)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    # Return the model
    return model

# %%
# Build the model with specified input and output shapes
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ Input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1 (Conv2D)              │ (None, 96, 96, 32)    │        896 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act1 (Activation)           │ (None, 96, 96, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp1 (MaxPooling2D)          │ (None, 48, 48, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2 (Conv2D)              │ (None, 48, 48, 64)    │     18,496 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act2 (Activation)           │ (None, 48, 48, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp2 (MaxPooling2D)          │ (None, 24, 24, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten (Flatten)           │ (None, 36864)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 8)             │    294,920 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ softmax (Activation)        │ (None, 8)             │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 314,312 (1.20 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 🛠️ Train and Save the Model

# %%
# Define the patience value for early stopping
patience = 10 # parameter to tune

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Store the callback in a list
callbacks = [early_stopping]

# %%
X_train.shape,y_train.shape
# Out:
# ((18720, 96, 96, 3), (18720, 8))

# %%
'''# Train the model with early stopping callback
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=callbacks
).history


# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')


# Save the trained model to a file with the accuracy included in the filename
model_filename = 'cell_v1'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model'''
# Out:
# "# Train the model with early stopping callback\nhistory = model.fit(\n    x=X_train,\n    y=y_train,\n    batch_size=batch_size,\n    epochs=epochs,\n    validation_data=(X_val, y_val),\n    callbacks=callbacks\n).history\n\n\n# Calculate and print the final validation accuracy\nfinal_val_accuracy = round(max(history['val_accuracy'])* 100, 2)\nprint(f'Final validation accuracy: {final_val_accuracy}%')\n\n\n# Save the trained model to a file with the accuracy included in the filename\nmodel_filename = 'cell_v1'.keras'\nmodel.save(model_filename)\n\n# Delete the model to free up resources\ndel model"

# %%
'''# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(history['loss'], label='Training loss', alpha=.8)
plt.plot(history['val_loss'], label='Validation loss', alpha=.8)
plt.title('Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()'''
# Out:
# "# Plot training and validation loss\nplt.figure(figsize=(15, 2))\nplt.plot(history['loss'], label='Training loss', alpha=.8)\nplt.plot(history['val_loss'], label='Validation loss', alpha=.8)\nplt.title('Loss')\nplt.legend()\nplt.grid(alpha=.3)\n\n# Plot training and validation accuracy\nplt.figure(figsize=(15, 2))\nplt.plot(history['accuracy'], label='Training accuracy', alpha=.8)\nplt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)\nplt.title('Accuracy')\nplt.legend()\nplt.grid(alpha=.3)\nplt.show()"

# %% [markdown]
# ## 💡 K-Fold Cross-Validation

# %%
# Define the number of folds for cross-validation
num_folds = 5

# Initialize lists to store training histories, scores, and best epochs
histories = []
scores = []
best_epochs = []

# Create a KFold cross-validation object
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=seed)

# Loop through each fold
for fold_idx, (train_idx, valid_idx) in enumerate(kfold.split(X_train_val, y_train_val)):

    print("Starting training on fold num: {}".format(fold_idx+1))

    # Build a new dropout model for each fold
    k_model = build_model(input_shape)

    # Create an EarlyStopping callback
    early_stopping = tfk.callbacks.EarlyStopping(
        monitor='val_mse',
        mode='min',
        patience=patience,
        restore_best_weights=True
    )

    callbacks = [early_stopping]

    # Train the model on the training data for this fold
    history = k_model.fit(
    x = X_train_val[train_idx],
    y = y_train_val[train_idx],
    validation_data=(X_train_val[valid_idx], y_train_val[valid_idx]),
    batch_size = batch_size,
    epochs = epochs,
    callbacks = callbacks,
    verbose = 1
    ).history

    # Evaluate the model on the validation data for this fold
    score = k_model.evaluate(X_train_val[valid_idx], y_train_val[valid_idx], verbose=0)
    scores.append(score[1])

    # Calculate the best epoch for early stopping
    best_epoch = len(history['loss']) - patience
    best_epochs.append(best_epoch)

    # Store the training history for this fold
    histories.append(history)
# Out:
# Starting training on fold num: 1
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731189499.745933     100 service.cc:145] XLA service 0x5686cd4e0eb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731189499.745995     100 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  29/494 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1355 - loss: 2.3776
# I0000 00:00:1731189501.858375     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3611 - loss: 1.6896 - val_accuracy: 0.6065 - val_loss: 1.0749
# Epoch 2/100
#  28/494 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6131 - loss: 1.0109
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_mse` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6167 - loss: 1.0036 - val_accuracy: 0.6731 - val_loss: 0.8955
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6883 - loss: 0.8267 - val_accuracy: 0.6969 - val_loss: 0.8574
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7258 - loss: 0.7362 - val_accuracy: 0.6946 - val_loss: 0.8550
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7515 - loss: 0.6690 - val_accuracy: 0.6903 - val_loss: 0.8944
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7747 - loss: 0.6114 - val_accuracy: 0.6961 - val_loss: 0.9051
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7970 - loss: 0.5570 - val_accuracy: 0.6898 - val_loss: 0.9530
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8168 - loss: 0.5086 - val_accuracy: 0.6872 - val_loss: 1.0375
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8287 - loss: 0.4788 - val_accuracy: 0.6943 - val_loss: 1.0349
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8423 - loss: 0.4453 - val_accuracy: 0.6966 - val_loss: 1.0317
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8509 - loss: 0.4121 - val_accuracy: 0.6953 - val_loss: 1.0659
# Epoch 12/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8595 - loss: 0.3929 - val_accuracy: 0.6913 - val_loss: 1.1290
# Epoch 13/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8606 - loss: 0.3846 - val_accuracy: 0.6875 - val_loss: 1.2495
# Epoch 14/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8676 - loss: 0.3655 - val_accuracy: 0.6996 - val_loss: 1.2284
# Epoch 15/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8753 - loss: 0.3444 - val_accuracy: 0.6855 - val_loss: 1.2981
# Epoch 16/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8807 - loss: 0.3306 - val_accuracy: 0.6910 - val_loss: 1.3692
# Epoch 17/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8847 - loss: 0.3251 - val_accuracy: 0.6895 - val_loss: 1.3617
# Epoch 18/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8826 - loss: 0.3141 - val_accuracy: 0.6953 - val_loss: 1.4100
# Epoch 19/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8901 - loss: 0.2950 - val_accuracy: 0.6918 - val_loss: 1.4396
# Epoch 20/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8908 - loss: 0.2973 - val_accuracy: 0.6943 - val_loss: 1.4949
# Epoch 21/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8934 - loss: 0.2874 - val_accuracy: 0.6971 - val_loss: 1.6316
# Epoch 22/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8989 - loss: 0.2753 - val_accuracy: 0.6933 - val_loss: 1.5940
# Epoch 23/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8986 - loss: 0.2722 - val_accuracy: 0.6956 - val_loss: 1.6551
# Epoch 24/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8991 - loss: 0.2741 - val_accuracy: 0.6835 - val_loss: 1.7893
# Epoch 25/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9056 - loss: 0.2619 - val_accuracy: 0.6832 - val_loss: 1.8936
# Epoch 26/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9067 - loss: 0.2596 - val_accuracy: 0.6933 - val_loss: 1.7100
# Epoch 27/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9070 - loss: 0.2514 - val_accuracy: 0.6948 - val_loss: 1.8060
# Epoch 28/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9136 - loss: 0.2424 - val_accuracy: 0.6809 - val_loss: 1.8119
# Epoch 29/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9126 - loss: 0.2405 - val_accuracy: 0.6979 - val_loss: 1.8752
# Epoch 30/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9169 - loss: 0.2345 - val_accuracy: 0.6921 - val_loss: 1.9801
# Epoch 31/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9154 - loss: 0.2341 - val_accuracy: 0.6855 - val_loss: 1.9214
# Epoch 32/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9103 - loss: 0.2447 - val_accuracy: 0.6779 - val_loss: 2.0890
# Epoch 33/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9105 - loss: 0.2452 - val_accuracy: 0.6870 - val_loss: 1.9837
# Epoch 34/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9189 - loss: 0.2211 - val_accuracy: 0.6789 - val_loss: 2.0566
# Epoch 35/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9210 - loss: 0.2142 - val_accuracy: 0.6943 - val_loss: 2.0768
# Epoch 36/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9227 - loss: 0.2133 - val_accuracy: 0.6779 - val_loss: 2.2550
# Epoch 37/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9213 - loss: 0.2110 - val_accuracy: 0.6723 - val_loss: 2.2702
# Epoch 38/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9187 - loss: 0.2163 - val_accuracy: 0.6799 - val_loss: 2.2866
# Epoch 39/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9251 - loss: 0.2037 - val_accuracy: 0.6817 - val_loss: 2.4189
# Epoch 40/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9214 - loss: 0.2125 - val_accuracy: 0.6898 - val_loss: 2.2911
# Epoch 41/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9180 - loss: 0.2205 - val_accuracy: 0.6759 - val_loss: 2.4692
# Epoch 42/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9238 - loss: 0.2051 - val_accuracy: 0.6835 - val_loss: 2.4415
# Epoch 43/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9235 - loss: 0.2052 - val_accuracy: 0.6789 - val_loss: 2.5254
# Epoch 44/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1930 - val_accuracy: 0.6726 - val_loss: 2.5549
# Epoch 45/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9289 - loss: 0.1889 - val_accuracy: 0.6716 - val_loss: 2.5507
# Epoch 46/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9154 - loss: 0.2267 - val_accuracy: 0.6784 - val_loss: 2.5923
# Epoch 47/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9259 - loss: 0.1950 - val_accuracy: 0.6776 - val_loss: 2.6268
# Epoch 48/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9287 - loss: 0.1853 - val_accuracy: 0.6759 - val_loss: 2.7292
# Epoch 49/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9315 - loss: 0.1800 - val_accuracy: 0.6521 - val_loss: 2.8696
# Epoch 50/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9238 - loss: 0.2053 - val_accuracy: 0.6754 - val_loss: 2.5386
# Epoch 51/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9231 - loss: 0.2046 - val_accuracy: 0.6850 - val_loss: 2.6065
# Epoch 52/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9310 - loss: 0.1884 - val_accuracy: 0.6875 - val_loss: 2.5111
# Epoch 53/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9298 - loss: 0.1875 - val_accuracy: 0.6733 - val_loss: 2.6813
# Epoch 54/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9286 - loss: 0.1825 - val_accuracy: 0.6812 - val_loss: 2.6228
# Epoch 55/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9319 - loss: 0.1743 - val_accuracy: 0.6650 - val_loss: 2.9158
# Epoch 56/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9296 - loss: 0.1847 - val_accuracy: 0.6698 - val_loss: 2.9002
# Epoch 57/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9275 - loss: 0.1883 - val_accuracy: 0.6799 - val_loss: 2.7975
# Epoch 58/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9280 - loss: 0.1872 - val_accuracy: 0.6713 - val_loss: 3.0498
# Epoch 59/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9327 - loss: 0.1748 - val_accuracy: 0.6872 - val_loss: 2.7712
# Epoch 60/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9300 - loss: 0.1825 - val_accuracy: 0.6579 - val_loss: 3.0826
# Epoch 61/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1940 - val_accuracy: 0.6878 - val_loss: 2.7833
# Epoch 62/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9284 - loss: 0.1869 - val_accuracy: 0.6751 - val_loss: 2.8794
# Epoch 63/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9301 - loss: 0.1787 - val_accuracy: 0.6824 - val_loss: 2.8526
# Epoch 64/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9334 - loss: 0.1729 - val_accuracy: 0.6814 - val_loss: 2.8273
# Epoch 65/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9320 - loss: 0.1734 - val_accuracy: 0.6748 - val_loss: 3.0222
# Epoch 66/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9312 - loss: 0.1790 - val_accuracy: 0.6771 - val_loss: 3.0538
# Epoch 67/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1818 - val_accuracy: 0.6789 - val_loss: 3.0158
# Epoch 68/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9332 - loss: 0.1699 - val_accuracy: 0.6695 - val_loss: 3.0547
# Epoch 69/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9298 - loss: 0.1770 - val_accuracy: 0.6809 - val_loss: 2.9793
# Epoch 70/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9313 - loss: 0.1760 - val_accuracy: 0.6564 - val_loss: 3.3822
# Epoch 71/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9313 - loss: 0.1761 - val_accuracy: 0.6807 - val_loss: 3.0225
# Epoch 72/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9293 - loss: 0.1804 - val_accuracy: 0.6764 - val_loss: 3.2915
# Epoch 73/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9300 - loss: 0.1750 - val_accuracy: 0.6766 - val_loss: 3.1793
# Epoch 74/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9288 - loss: 0.1824 - val_accuracy: 0.6814 - val_loss: 3.3639
# Epoch 75/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9284 - loss: 0.1820 - val_accuracy: 0.6756 - val_loss: 3.3300
# Epoch 76/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9276 - loss: 0.1837 - val_accuracy: 0.6893 - val_loss: 3.2450
# Epoch 77/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9331 - loss: 0.1657 - val_accuracy: 0.6923 - val_loss: 3.0802
# Epoch 78/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9328 - loss: 0.1688 - val_accuracy: 0.6855 - val_loss: 3.2140
# Epoch 79/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9301 - loss: 0.1722 - val_accuracy: 0.6364 - val_loss: 4.2216
# Epoch 80/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9267 - loss: 0.2012 - val_accuracy: 0.6837 - val_loss: 3.4325
# Epoch 81/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9342 - loss: 0.1616 - val_accuracy: 0.6845 - val_loss: 3.5649
# Epoch 82/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9351 - loss: 0.1607 - val_accuracy: 0.6791 - val_loss: 3.4635
# Epoch 83/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9229 - loss: 0.2037 - val_accuracy: 0.6840 - val_loss: 3.6161
# Epoch 84/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9286 - loss: 0.1861 - val_accuracy: 0.6878 - val_loss: 3.3538
# Epoch 85/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9331 - loss: 0.1676 - val_accuracy: 0.6786 - val_loss: 3.3574
# Epoch 86/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9326 - loss: 0.1688 - val_accuracy: 0.6561 - val_loss: 3.9034
# Epoch 87/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9280 - loss: 0.1921 - val_accuracy: 0.6726 - val_loss: 3.4445
# Epoch 88/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9320 - loss: 0.1682 - val_accuracy: 0.6835 - val_loss: 3.3752
# Epoch 89/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9338 - loss: 0.1617 - val_accuracy: 0.6786 - val_loss: 3.6418
# Epoch 90/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9261 - loss: 0.1950 - val_accuracy: 0.6895 - val_loss: 3.3270
# Epoch 91/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9291 - loss: 0.1781 - val_accuracy: 0.6880 - val_loss: 3.2695
# Epoch 92/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9326 - loss: 0.1721 - val_accuracy: 0.6748 - val_loss: 3.6210
# Epoch 93/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9315 - loss: 0.1651 - val_accuracy: 0.6761 - val_loss: 3.5330
# Epoch 94/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9317 - loss: 0.1682 - val_accuracy: 0.6733 - val_loss: 3.7891
# Epoch 95/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9321 - loss: 0.1693 - val_accuracy: 0.6890 - val_loss: 3.5606
# Epoch 96/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9311 - loss: 0.1734 - val_accuracy: 0.6789 - val_loss: 3.7093
# Epoch 97/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9336 - loss: 0.1658 - val_accuracy: 0.6829 - val_loss: 3.9050
# Epoch 98/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9336 - loss: 0.1612 - val_accuracy: 0.6862 - val_loss: 3.7048
# Epoch 99/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9308 - loss: 0.1685 - val_accuracy: 0.6870 - val_loss: 3.7833
# Epoch 100/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9345 - loss: 0.1626 - val_accuracy: 0.6541 - val_loss: 4.0740
# Starting training on fold num: 2
# Epoch 1/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3461 - loss: 1.7400 - val_accuracy: 0.6189 - val_loss: 1.0395
# Epoch 2/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6380 - loss: 0.9816 - val_accuracy: 0.6642 - val_loss: 0.8814
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6954 - loss: 0.8248 - val_accuracy: 0.6979 - val_loss: 0.8134
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7347 - loss: 0.7227 - val_accuracy: 0.7143 - val_loss: 0.7765
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7668 - loss: 0.6387 - val_accuracy: 0.7161 - val_loss: 0.7990
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7951 - loss: 0.5716 - val_accuracy: 0.7110 - val_loss: 0.8499
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8103 - loss: 0.5275 - val_accuracy: 0.7009 - val_loss: 0.9062
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8315 - loss: 0.4777 - val_accuracy: 0.6981 - val_loss: 0.9527
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8412 - loss: 0.4386 - val_accuracy: 0.7027 - val_loss: 0.9649
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8603 - loss: 0.4009 - val_accuracy: 0.6991 - val_loss: 1.0095
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8652 - loss: 0.3801 - val_accuracy: 0.6971 - val_loss: 1.0530
# Epoch 12/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8741 - loss: 0.3605 - val_accuracy: 0.6953 - val_loss: 1.0816
# Epoch 13/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8807 - loss: 0.3411 - val_accuracy: 0.6872 - val_loss: 1.1726
# Epoch 14/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8856 - loss: 0.3222 - val_accuracy: 0.6979 - val_loss: 1.1977
# Epoch 15/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8905 - loss: 0.3107 - val_accuracy: 0.6964 - val_loss: 1.2411
# Epoch 16/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8870 - loss: 0.3147 - val_accuracy: 0.6852 - val_loss: 1.3578
# Epoch 17/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8958 - loss: 0.2883 - val_accuracy: 0.6999 - val_loss: 1.3647
# Epoch 18/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9023 - loss: 0.2762 - val_accuracy: 0.6918 - val_loss: 1.4386
# Epoch 19/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9028 - loss: 0.2728 - val_accuracy: 0.6913 - val_loss: 1.4896
# Epoch 20/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9036 - loss: 0.2659 - val_accuracy: 0.7065 - val_loss: 1.3587
# Epoch 21/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9043 - loss: 0.2588 - val_accuracy: 0.6923 - val_loss: 1.4783
# Epoch 22/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9083 - loss: 0.2535 - val_accuracy: 0.6865 - val_loss: 1.6595
# Epoch 23/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9095 - loss: 0.2499 - val_accuracy: 0.6880 - val_loss: 1.6588
# Epoch 24/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9106 - loss: 0.2435 - val_accuracy: 0.6953 - val_loss: 1.6201
# Epoch 25/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9142 - loss: 0.2306 - val_accuracy: 0.6878 - val_loss: 1.7189
# Epoch 26/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9142 - loss: 0.2363 - val_accuracy: 0.7014 - val_loss: 1.6683
# Epoch 27/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9196 - loss: 0.2230 - val_accuracy: 0.6807 - val_loss: 1.9022
# Epoch 28/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9151 - loss: 0.2277 - val_accuracy: 0.6837 - val_loss: 1.8984
# Epoch 29/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9194 - loss: 0.2182 - val_accuracy: 0.6900 - val_loss: 1.8840
# Epoch 30/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9184 - loss: 0.2179 - val_accuracy: 0.6921 - val_loss: 1.8948
# Epoch 31/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9186 - loss: 0.2182 - val_accuracy: 0.6931 - val_loss: 1.9514
# Epoch 32/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9224 - loss: 0.2084 - val_accuracy: 0.6905 - val_loss: 1.8918
# Epoch 33/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9212 - loss: 0.2085 - val_accuracy: 0.6791 - val_loss: 1.9377
# Epoch 34/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9188 - loss: 0.2129 - val_accuracy: 0.6855 - val_loss: 1.9921
# Epoch 35/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9211 - loss: 0.2090 - val_accuracy: 0.6875 - val_loss: 1.9245
# Epoch 36/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9227 - loss: 0.2052 - val_accuracy: 0.6984 - val_loss: 1.8869
# Epoch 37/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9205 - loss: 0.2131 - val_accuracy: 0.7034 - val_loss: 1.8455
# Epoch 38/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9211 - loss: 0.2064 - val_accuracy: 0.6953 - val_loss: 1.9770
# Epoch 39/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9266 - loss: 0.1977 - val_accuracy: 0.6921 - val_loss: 2.0057
# Epoch 40/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9234 - loss: 0.2021 - val_accuracy: 0.6910 - val_loss: 1.9966
# Epoch 41/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1996 - val_accuracy: 0.6883 - val_loss: 2.0390
# Epoch 42/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1972 - val_accuracy: 0.6943 - val_loss: 2.0468
# Epoch 43/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9256 - loss: 0.1941 - val_accuracy: 0.6769 - val_loss: 2.3121
# Epoch 44/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9221 - loss: 0.2055 - val_accuracy: 0.6700 - val_loss: 2.4400
# Epoch 45/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1981 - val_accuracy: 0.6807 - val_loss: 2.3302
# Epoch 46/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1927 - val_accuracy: 0.6857 - val_loss: 2.3356
# Epoch 47/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9270 - loss: 0.1912 - val_accuracy: 0.6948 - val_loss: 2.2018
# Epoch 48/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9290 - loss: 0.1864 - val_accuracy: 0.6938 - val_loss: 2.3182
# Epoch 49/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9255 - loss: 0.1963 - val_accuracy: 0.6840 - val_loss: 2.3634
# Epoch 50/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9246 - loss: 0.2007 - val_accuracy: 0.6872 - val_loss: 2.2651
# Epoch 51/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1882 - val_accuracy: 0.6915 - val_loss: 2.3377
# Epoch 52/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9281 - loss: 0.1856 - val_accuracy: 0.6959 - val_loss: 2.3571
# Epoch 53/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9300 - loss: 0.1832 - val_accuracy: 0.6905 - val_loss: 2.3697
# Epoch 54/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9288 - loss: 0.1831 - val_accuracy: 0.6908 - val_loss: 2.2381
# Epoch 55/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9321 - loss: 0.1768 - val_accuracy: 0.7019 - val_loss: 2.2799
# Epoch 56/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9314 - loss: 0.1766 - val_accuracy: 0.6893 - val_loss: 2.4343
# Epoch 57/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9289 - loss: 0.1808 - val_accuracy: 0.6910 - val_loss: 2.3180
# Epoch 58/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9287 - loss: 0.1808 - val_accuracy: 0.7034 - val_loss: 2.3354
# Epoch 59/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9287 - loss: 0.1852 - val_accuracy: 0.6951 - val_loss: 2.3849
# Epoch 60/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9293 - loss: 0.1891 - val_accuracy: 0.6928 - val_loss: 2.4424
# Epoch 61/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9316 - loss: 0.1751 - val_accuracy: 0.6794 - val_loss: 2.7388
# Epoch 62/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9291 - loss: 0.1818 - val_accuracy: 0.6966 - val_loss: 2.4544
# Epoch 63/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9312 - loss: 0.1742 - val_accuracy: 0.6933 - val_loss: 2.5365
# Epoch 64/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9307 - loss: 0.1706 - val_accuracy: 0.6883 - val_loss: 2.8307
# Epoch 65/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9292 - loss: 0.1816 - val_accuracy: 0.6893 - val_loss: 2.6477
# Epoch 66/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9304 - loss: 0.1788 - val_accuracy: 0.6933 - val_loss: 2.5437
# Epoch 67/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9331 - loss: 0.1696 - val_accuracy: 0.7014 - val_loss: 2.5520
# Epoch 68/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9349 - loss: 0.1665 - val_accuracy: 0.6913 - val_loss: 2.5687
# Epoch 69/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9302 - loss: 0.1771 - val_accuracy: 0.6784 - val_loss: 2.7745
# Epoch 70/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9269 - loss: 0.1944 - val_accuracy: 0.6781 - val_loss: 2.9118
# Epoch 71/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9258 - loss: 0.1846 - val_accuracy: 0.6969 - val_loss: 2.7159
# Epoch 72/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9331 - loss: 0.1685 - val_accuracy: 0.7014 - val_loss: 2.6293
# Epoch 73/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9321 - loss: 0.1696 - val_accuracy: 0.6948 - val_loss: 2.6190
# Epoch 74/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9308 - loss: 0.1730 - val_accuracy: 0.6943 - val_loss: 2.7638
# Epoch 75/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9317 - loss: 0.1684 - val_accuracy: 0.6956 - val_loss: 2.6515
# Epoch 76/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1860 - val_accuracy: 0.6875 - val_loss: 2.5435
# Epoch 77/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9316 - loss: 0.1736 - val_accuracy: 0.6893 - val_loss: 2.9866
# Epoch 78/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9284 - loss: 0.1765 - val_accuracy: 0.6981 - val_loss: 2.7874
# Epoch 79/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9341 - loss: 0.1668 - val_accuracy: 0.6959 - val_loss: 2.9079
# Epoch 80/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9316 - loss: 0.1746 - val_accuracy: 0.6898 - val_loss: 2.8170
# Epoch 81/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9292 - loss: 0.1821 - val_accuracy: 0.6890 - val_loss: 2.9468
# Epoch 82/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9320 - loss: 0.1717 - val_accuracy: 0.6936 - val_loss: 2.9374
# Epoch 83/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9328 - loss: 0.1680 - val_accuracy: 0.6991 - val_loss: 2.8504
# Epoch 84/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9301 - loss: 0.1790 - val_accuracy: 0.6931 - val_loss: 2.8564
# Epoch 85/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1712 - val_accuracy: 0.6903 - val_loss: 2.8978
# Epoch 86/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9335 - loss: 0.1670 - val_accuracy: 0.6860 - val_loss: 3.0099
# Epoch 87/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9308 - loss: 0.1739 - val_accuracy: 0.6857 - val_loss: 2.9628
# Epoch 88/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9347 - loss: 0.1642 - val_accuracy: 0.6926 - val_loss: 3.0414
# Epoch 89/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9314 - loss: 0.1755 - val_accuracy: 0.6812 - val_loss: 3.3167
# Epoch 90/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9284 - loss: 0.1841 - val_accuracy: 0.6865 - val_loss: 3.0746
# Epoch 91/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9310 - loss: 0.1744 - val_accuracy: 0.6959 - val_loss: 3.0517
# Epoch 92/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9335 - loss: 0.1642 - val_accuracy: 0.6948 - val_loss: 3.0829
# Epoch 93/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9348 - loss: 0.1610 - val_accuracy: 0.6961 - val_loss: 2.9844
# Epoch 94/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9363 - loss: 0.1593 - val_accuracy: 0.6931 - val_loss: 3.1072
# Epoch 95/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9308 - loss: 0.1736 - val_accuracy: 0.6685 - val_loss: 3.1154
# Epoch 96/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9296 - loss: 0.1806 - val_accuracy: 0.6748 - val_loss: 3.2198
# Epoch 97/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9305 - loss: 0.1678 - val_accuracy: 0.6865 - val_loss: 3.3115
# Epoch 98/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9330 - loss: 0.1629 - val_accuracy: 0.6829 - val_loss: 3.1915
# Epoch 99/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9350 - loss: 0.1606 - val_accuracy: 0.6888 - val_loss: 3.1707
# Epoch 100/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9365 - loss: 0.1587 - val_accuracy: 0.6779 - val_loss: 3.3795
# Starting training on fold num: 3
# Epoch 1/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3656 - loss: 1.6566 - val_accuracy: 0.5777 - val_loss: 1.1162
# Epoch 2/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6271 - loss: 1.0346 - val_accuracy: 0.6559 - val_loss: 0.9427
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6880 - loss: 0.8599 - val_accuracy: 0.6771 - val_loss: 0.8709
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7274 - loss: 0.7563 - val_accuracy: 0.6905 - val_loss: 0.8530
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7571 - loss: 0.6831 - val_accuracy: 0.6966 - val_loss: 0.8534
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7831 - loss: 0.6160 - val_accuracy: 0.7050 - val_loss: 0.8458
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8032 - loss: 0.5553 - val_accuracy: 0.6981 - val_loss: 0.8664
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8198 - loss: 0.5097 - val_accuracy: 0.6969 - val_loss: 0.8990
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8343 - loss: 0.4679 - val_accuracy: 0.6910 - val_loss: 0.9477
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8457 - loss: 0.4319 - val_accuracy: 0.6867 - val_loss: 1.0251
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8547 - loss: 0.4052 - val_accuracy: 0.7002 - val_loss: 1.0159
# Epoch 12/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8629 - loss: 0.3839 - val_accuracy: 0.6885 - val_loss: 1.0890
# Epoch 13/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8723 - loss: 0.3611 - val_accuracy: 0.6855 - val_loss: 1.1612
# Epoch 14/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8741 - loss: 0.3459 - val_accuracy: 0.6890 - val_loss: 1.1815
# Epoch 15/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8802 - loss: 0.3393 - val_accuracy: 0.6903 - val_loss: 1.2614
# Epoch 16/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8799 - loss: 0.3359 - val_accuracy: 0.6809 - val_loss: 1.3323
# Epoch 17/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8795 - loss: 0.3284 - val_accuracy: 0.6875 - val_loss: 1.3425
# Epoch 18/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8807 - loss: 0.3283 - val_accuracy: 0.6819 - val_loss: 1.4226
# Epoch 19/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8925 - loss: 0.3000 - val_accuracy: 0.6913 - val_loss: 1.4119
# Epoch 20/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8898 - loss: 0.2999 - val_accuracy: 0.6794 - val_loss: 1.5701
# Epoch 21/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8930 - loss: 0.2995 - val_accuracy: 0.6943 - val_loss: 1.4677
# Epoch 22/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8955 - loss: 0.2812 - val_accuracy: 0.7002 - val_loss: 1.4725
# Epoch 23/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8975 - loss: 0.2724 - val_accuracy: 0.7017 - val_loss: 1.5187
# Epoch 24/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9040 - loss: 0.2589 - val_accuracy: 0.6933 - val_loss: 1.5955
# Epoch 25/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9072 - loss: 0.2547 - val_accuracy: 0.6814 - val_loss: 1.7272
# Epoch 26/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9072 - loss: 0.2501 - val_accuracy: 0.6941 - val_loss: 1.5981
# Epoch 27/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9062 - loss: 0.2460 - val_accuracy: 0.6913 - val_loss: 1.7082
# Epoch 28/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9115 - loss: 0.2373 - val_accuracy: 0.6804 - val_loss: 1.8466
# Epoch 29/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9166 - loss: 0.2357 - val_accuracy: 0.6905 - val_loss: 1.7654
# Epoch 30/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9150 - loss: 0.2288 - val_accuracy: 0.6549 - val_loss: 2.0316
# Epoch 31/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9084 - loss: 0.2430 - val_accuracy: 0.6847 - val_loss: 1.8214
# Epoch 32/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9166 - loss: 0.2228 - val_accuracy: 0.6938 - val_loss: 1.8289
# Epoch 33/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9170 - loss: 0.2171 - val_accuracy: 0.6921 - val_loss: 1.9194
# Epoch 34/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9146 - loss: 0.2249 - val_accuracy: 0.6890 - val_loss: 1.9576
# Epoch 35/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9144 - loss: 0.2258 - val_accuracy: 0.6791 - val_loss: 2.0095
# Epoch 36/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9192 - loss: 0.2164 - val_accuracy: 0.6880 - val_loss: 1.9694
# Epoch 37/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9171 - loss: 0.2174 - val_accuracy: 0.6948 - val_loss: 2.0007
# Epoch 38/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9237 - loss: 0.2025 - val_accuracy: 0.6819 - val_loss: 2.2232
# Epoch 39/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9211 - loss: 0.2077 - val_accuracy: 0.6860 - val_loss: 2.2313
# Epoch 40/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9200 - loss: 0.2133 - val_accuracy: 0.6829 - val_loss: 2.3374
# Epoch 41/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9178 - loss: 0.2121 - val_accuracy: 0.6923 - val_loss: 2.1395
# Epoch 42/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9226 - loss: 0.2003 - val_accuracy: 0.6870 - val_loss: 2.2545
# Epoch 43/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9240 - loss: 0.1993 - val_accuracy: 0.6812 - val_loss: 2.3451
# Epoch 44/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9207 - loss: 0.2069 - val_accuracy: 0.6769 - val_loss: 2.2697
# Epoch 45/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9197 - loss: 0.2147 - val_accuracy: 0.6898 - val_loss: 2.1745
# Epoch 46/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9249 - loss: 0.1921 - val_accuracy: 0.6883 - val_loss: 2.2443
# Epoch 47/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9278 - loss: 0.1921 - val_accuracy: 0.6857 - val_loss: 2.3072
# Epoch 48/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9266 - loss: 0.1912 - val_accuracy: 0.6781 - val_loss: 2.4090
# Epoch 49/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9224 - loss: 0.2087 - val_accuracy: 0.6842 - val_loss: 2.3535
# Epoch 50/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9255 - loss: 0.1964 - val_accuracy: 0.6865 - val_loss: 2.3908
# Epoch 51/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9259 - loss: 0.1916 - val_accuracy: 0.6855 - val_loss: 2.4580
# Epoch 52/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9271 - loss: 0.1918 - val_accuracy: 0.6827 - val_loss: 2.4936
# Epoch 53/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9277 - loss: 0.1887 - val_accuracy: 0.6680 - val_loss: 2.6596
# Epoch 54/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9280 - loss: 0.1846 - val_accuracy: 0.6721 - val_loss: 2.9292
# Epoch 55/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9268 - loss: 0.1882 - val_accuracy: 0.6748 - val_loss: 2.6930
# Epoch 56/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9260 - loss: 0.1928 - val_accuracy: 0.6736 - val_loss: 2.7287
# Epoch 57/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9275 - loss: 0.1840 - val_accuracy: 0.6840 - val_loss: 2.6757
# Epoch 58/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9267 - loss: 0.1921 - val_accuracy: 0.6837 - val_loss: 2.7657
# Epoch 59/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9279 - loss: 0.1863 - val_accuracy: 0.6716 - val_loss: 2.9079
# Epoch 60/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9226 - loss: 0.1968 - val_accuracy: 0.6812 - val_loss: 2.7266
# Epoch 61/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9270 - loss: 0.1895 - val_accuracy: 0.6883 - val_loss: 2.7799
# Epoch 62/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9270 - loss: 0.1867 - val_accuracy: 0.6969 - val_loss: 2.7051
# Epoch 63/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9316 - loss: 0.1735 - val_accuracy: 0.6903 - val_loss: 2.7545
# Epoch 64/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9326 - loss: 0.1702 - val_accuracy: 0.6903 - val_loss: 2.7789
# Epoch 65/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9263 - loss: 0.1888 - val_accuracy: 0.6774 - val_loss: 3.0041
# Epoch 66/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9237 - loss: 0.1931 - val_accuracy: 0.6890 - val_loss: 2.8480
# Epoch 67/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1755 - val_accuracy: 0.6827 - val_loss: 2.9185
# Epoch 68/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9294 - loss: 0.1783 - val_accuracy: 0.6814 - val_loss: 2.8974
# Epoch 69/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9317 - loss: 0.1756 - val_accuracy: 0.6759 - val_loss: 2.9284
# Epoch 70/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9228 - loss: 0.1919 - val_accuracy: 0.6852 - val_loss: 2.9081
# Epoch 71/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9307 - loss: 0.1774 - val_accuracy: 0.6850 - val_loss: 2.9713
# Epoch 72/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9309 - loss: 0.1712 - val_accuracy: 0.6751 - val_loss: 3.0627
# Epoch 73/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9270 - loss: 0.1839 - val_accuracy: 0.6776 - val_loss: 3.0014
# Epoch 74/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9270 - loss: 0.1853 - val_accuracy: 0.6726 - val_loss: 3.0890
# Epoch 75/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9289 - loss: 0.1824 - val_accuracy: 0.6827 - val_loss: 2.9669
# Epoch 76/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9284 - loss: 0.1739 - val_accuracy: 0.6759 - val_loss: 3.0217
# Epoch 77/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9300 - loss: 0.1752 - val_accuracy: 0.6766 - val_loss: 3.0649
# Epoch 78/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9296 - loss: 0.1746 - val_accuracy: 0.6713 - val_loss: 3.3159
# Epoch 79/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9247 - loss: 0.1918 - val_accuracy: 0.6726 - val_loss: 3.1354
# Epoch 80/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9275 - loss: 0.1800 - val_accuracy: 0.6915 - val_loss: 3.0332
# Epoch 81/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9319 - loss: 0.1693 - val_accuracy: 0.6837 - val_loss: 2.9934
# Epoch 82/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9297 - loss: 0.1740 - val_accuracy: 0.6647 - val_loss: 3.3086
# Epoch 83/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9226 - loss: 0.2030 - val_accuracy: 0.6898 - val_loss: 3.0363
# Epoch 84/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9318 - loss: 0.1732 - val_accuracy: 0.6847 - val_loss: 3.0824
# Epoch 85/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1737 - val_accuracy: 0.6837 - val_loss: 3.1805
# Epoch 86/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9298 - loss: 0.1720 - val_accuracy: 0.6928 - val_loss: 3.1682
# Epoch 87/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9323 - loss: 0.1660 - val_accuracy: 0.6913 - val_loss: 3.1035
# Epoch 88/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9317 - loss: 0.1648 - val_accuracy: 0.6728 - val_loss: 3.5290
# Epoch 89/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9211 - loss: 0.2041 - val_accuracy: 0.6705 - val_loss: 3.3016
# Epoch 90/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9291 - loss: 0.1775 - val_accuracy: 0.6822 - val_loss: 3.3686
# Epoch 91/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1736 - val_accuracy: 0.6850 - val_loss: 3.3743
# Epoch 92/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9319 - loss: 0.1669 - val_accuracy: 0.6875 - val_loss: 3.3965
# Epoch 93/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1741 - val_accuracy: 0.6764 - val_loss: 3.2428
# Epoch 94/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9312 - loss: 0.1685 - val_accuracy: 0.6840 - val_loss: 3.4592
# Epoch 95/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9318 - loss: 0.1680 - val_accuracy: 0.6819 - val_loss: 3.3995
# Epoch 96/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9305 - loss: 0.1680 - val_accuracy: 0.6809 - val_loss: 3.5485
# Epoch 97/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9256 - loss: 0.1900 - val_accuracy: 0.6837 - val_loss: 3.6797
# Epoch 98/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9313 - loss: 0.1723 - val_accuracy: 0.6781 - val_loss: 3.5695
# Epoch 99/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9315 - loss: 0.1708 - val_accuracy: 0.6756 - val_loss: 3.6462
# Epoch 100/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9219 - loss: 0.2136 - val_accuracy: 0.6769 - val_loss: 3.4776
# Starting training on fold num: 4
# Epoch 1/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3621 - loss: 1.6579 - val_accuracy: 0.6078 - val_loss: 1.0433
# Epoch 2/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6389 - loss: 0.9663 - val_accuracy: 0.6526 - val_loss: 0.9238
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7013 - loss: 0.8187 - val_accuracy: 0.6759 - val_loss: 0.8736
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7231 - loss: 0.7543 - val_accuracy: 0.6860 - val_loss: 0.8566
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7489 - loss: 0.6837 - val_accuracy: 0.6880 - val_loss: 0.8438
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7742 - loss: 0.6247 - val_accuracy: 0.6690 - val_loss: 0.9085
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7962 - loss: 0.5731 - val_accuracy: 0.6703 - val_loss: 0.9581
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8046 - loss: 0.5446 - val_accuracy: 0.6668 - val_loss: 0.9991
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8197 - loss: 0.5004 - val_accuracy: 0.6528 - val_loss: 1.0670
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8380 - loss: 0.4628 - val_accuracy: 0.6683 - val_loss: 1.0752
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8447 - loss: 0.4403 - val_accuracy: 0.6632 - val_loss: 1.1329
# Epoch 12/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8554 - loss: 0.4024 - val_accuracy: 0.6688 - val_loss: 1.1355
# Epoch 13/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8653 - loss: 0.3836 - val_accuracy: 0.6554 - val_loss: 1.2281
# Epoch 14/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8655 - loss: 0.3766 - val_accuracy: 0.6546 - val_loss: 1.3219
# Epoch 15/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8726 - loss: 0.3568 - val_accuracy: 0.6789 - val_loss: 1.2623
# Epoch 16/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8695 - loss: 0.3596 - val_accuracy: 0.6824 - val_loss: 1.1937
# Epoch 17/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8791 - loss: 0.3384 - val_accuracy: 0.6822 - val_loss: 1.2654
# Epoch 18/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8882 - loss: 0.3169 - val_accuracy: 0.6624 - val_loss: 1.3767
# Epoch 19/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8899 - loss: 0.3115 - val_accuracy: 0.6673 - val_loss: 1.4907
# Epoch 20/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8900 - loss: 0.3016 - val_accuracy: 0.6845 - val_loss: 1.3422
# Epoch 21/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8993 - loss: 0.2771 - val_accuracy: 0.6807 - val_loss: 1.4262
# Epoch 22/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9026 - loss: 0.2715 - val_accuracy: 0.6852 - val_loss: 1.4700
# Epoch 23/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9076 - loss: 0.2558 - val_accuracy: 0.6640 - val_loss: 1.6025
# Epoch 24/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9106 - loss: 0.2448 - val_accuracy: 0.6619 - val_loss: 1.6692
# Epoch 25/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9061 - loss: 0.2572 - val_accuracy: 0.6703 - val_loss: 1.7529
# Epoch 26/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9099 - loss: 0.2523 - val_accuracy: 0.6862 - val_loss: 1.6864
# Epoch 27/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9120 - loss: 0.2409 - val_accuracy: 0.6726 - val_loss: 1.6606
# Epoch 28/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9137 - loss: 0.2437 - val_accuracy: 0.6786 - val_loss: 1.7314
# Epoch 29/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9132 - loss: 0.2381 - val_accuracy: 0.6731 - val_loss: 1.7870
# Epoch 30/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9181 - loss: 0.2293 - val_accuracy: 0.6769 - val_loss: 1.8114
# Epoch 31/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9205 - loss: 0.2173 - val_accuracy: 0.6766 - val_loss: 1.9416
# Epoch 32/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9190 - loss: 0.2196 - val_accuracy: 0.6733 - val_loss: 1.9259
# Epoch 33/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9222 - loss: 0.2154 - val_accuracy: 0.6819 - val_loss: 1.9056
# Epoch 34/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9238 - loss: 0.2083 - val_accuracy: 0.6784 - val_loss: 2.1143
# Epoch 35/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9240 - loss: 0.2073 - val_accuracy: 0.6862 - val_loss: 1.9407
# Epoch 36/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9235 - loss: 0.2044 - val_accuracy: 0.6779 - val_loss: 2.0463
# Epoch 37/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9260 - loss: 0.1980 - val_accuracy: 0.6827 - val_loss: 1.9589
# Epoch 38/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9277 - loss: 0.1978 - val_accuracy: 0.6650 - val_loss: 2.2644
# Epoch 39/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9262 - loss: 0.1974 - val_accuracy: 0.6779 - val_loss: 2.1159
# Epoch 40/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9275 - loss: 0.1925 - val_accuracy: 0.6819 - val_loss: 2.1252
# Epoch 41/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9272 - loss: 0.1917 - val_accuracy: 0.6855 - val_loss: 2.2569
# Epoch 42/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9247 - loss: 0.1988 - val_accuracy: 0.6690 - val_loss: 2.2721
# Epoch 43/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9274 - loss: 0.1895 - val_accuracy: 0.6622 - val_loss: 2.2997
# Epoch 44/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9280 - loss: 0.1904 - val_accuracy: 0.6794 - val_loss: 2.3163
# Epoch 45/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9275 - loss: 0.1917 - val_accuracy: 0.6480 - val_loss: 2.4243
# Epoch 46/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9231 - loss: 0.2033 - val_accuracy: 0.6728 - val_loss: 2.2957
# Epoch 47/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9286 - loss: 0.1869 - val_accuracy: 0.6855 - val_loss: 2.2552
# Epoch 48/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9295 - loss: 0.1830 - val_accuracy: 0.6751 - val_loss: 2.3958
# Epoch 49/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9323 - loss: 0.1797 - val_accuracy: 0.6652 - val_loss: 2.4856
# Epoch 50/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9296 - loss: 0.1839 - val_accuracy: 0.6652 - val_loss: 2.4496
# Epoch 51/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9256 - loss: 0.1957 - val_accuracy: 0.6657 - val_loss: 2.4110
# Epoch 52/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9294 - loss: 0.1875 - val_accuracy: 0.6878 - val_loss: 2.2431
# Epoch 53/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9272 - loss: 0.1874 - val_accuracy: 0.6531 - val_loss: 2.5761
# Epoch 54/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9334 - loss: 0.1704 - val_accuracy: 0.6660 - val_loss: 2.4071
# Epoch 55/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9310 - loss: 0.1795 - val_accuracy: 0.6538 - val_loss: 2.5217
# Epoch 56/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9282 - loss: 0.1900 - val_accuracy: 0.6789 - val_loss: 2.4981
# Epoch 57/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9332 - loss: 0.1715 - val_accuracy: 0.6746 - val_loss: 2.4586
# Epoch 58/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9343 - loss: 0.1760 - val_accuracy: 0.6840 - val_loss: 2.5092
# Epoch 59/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9316 - loss: 0.1749 - val_accuracy: 0.6878 - val_loss: 2.5181
# Epoch 60/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9299 - loss: 0.1801 - val_accuracy: 0.6705 - val_loss: 2.4722
# Epoch 61/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9329 - loss: 0.1757 - val_accuracy: 0.6754 - val_loss: 2.6754
# Epoch 62/100
# ...
# Epoch 79/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9354 - loss: 0.1614 - val_accuracy: 0.6845 - val_loss: 2.8095
# Epoch 80/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9361 - loss: 0.1568 - val_accuracy: 0.6862 - val_loss: 3.0019
# Epoch 81/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9365 - loss: 0.1576 - val_accuracy: 0.6741 - val_loss: 3.0770
# Epoch 82/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9215 - loss: 0.2004 - val_accuracy: 0.6726 - val_loss: 2.8540
# Epoch 83/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9332 - loss: 0.1685 - val_accuracy: 0.6769 - val_loss: 2.9927
# Epoch 84/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9347 - loss: 0.1631 - val_accuracy: 0.6693 - val_loss: 2.9713
# Epoch 85/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9348 - loss: 0.1665 - val_accuracy: 0.6761 - val_loss: 3.0922
# Epoch 86/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9349 - loss: 0.1606 - val_accuracy: 0.6814 - val_loss: 2.8948
# Epoch 87/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9355 - loss: 0.1578 - val_accuracy: 0.6786 - val_loss: 3.1367
# Epoch 88/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9353 - loss: 0.1598 - val_accuracy: 0.6612 - val_loss: 3.0785
# Epoch 89/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9287 - loss: 0.1772 - val_accuracy: 0.6594 - val_loss: 3.1100
# Epoch 90/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9328 - loss: 0.1690 - val_accuracy: 0.6736 - val_loss: 3.1413
# Epoch 91/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9359 - loss: 0.1588 - val_accuracy: 0.6855 - val_loss: 2.9711
# Epoch 92/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9364 - loss: 0.1561 - val_accuracy: 0.6883 - val_loss: 2.9449
# Epoch 93/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9376 - loss: 0.1552 - val_accuracy: 0.6835 - val_loss: 2.9837
# Epoch 94/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9357 - loss: 0.1580 - val_accuracy: 0.6523 - val_loss: 3.2223
# Epoch 95/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9272 - loss: 0.1854 - val_accuracy: 0.6781 - val_loss: 3.2159
# Epoch 96/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9355 - loss: 0.1590 - val_accuracy: 0.6802 - val_loss: 3.1841
# Epoch 97/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9361 - loss: 0.1575 - val_accuracy: 0.6837 - val_loss: 3.1860
# Epoch 98/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9361 - loss: 0.1547 - val_accuracy: 0.6860 - val_loss: 3.2579
# Epoch 99/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9362 - loss: 0.1572 - val_accuracy: 0.6513 - val_loss: 3.2326
# Epoch 100/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9250 - loss: 0.1929 - val_accuracy: 0.6683 - val_loss: 3.3843
# Starting training on fold num: 5
# Epoch 1/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3739 - loss: 1.6482 - val_accuracy: 0.6202 - val_loss: 1.0162
# Epoch 2/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6380 - loss: 0.9733 - val_accuracy: 0.6705 - val_loss: 0.8741
# Epoch 3/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6988 - loss: 0.8236 - val_accuracy: 0.6923 - val_loss: 0.8127
# Epoch 4/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7307 - loss: 0.7400 - val_accuracy: 0.7055 - val_loss: 0.7949
# Epoch 5/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7600 - loss: 0.6639 - val_accuracy: 0.7012 - val_loss: 0.8054
# Epoch 6/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7814 - loss: 0.6097 - val_accuracy: 0.6852 - val_loss: 0.8527
# Epoch 7/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7966 - loss: 0.5708 - val_accuracy: 0.6959 - val_loss: 0.8745
# Epoch 8/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8208 - loss: 0.5067 - val_accuracy: 0.6986 - val_loss: 0.9206
# Epoch 9/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8289 - loss: 0.4727 - val_accuracy: 0.6791 - val_loss: 1.0148
# Epoch 10/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8453 - loss: 0.4297 - val_accuracy: 0.6665 - val_loss: 1.1395
# Epoch 11/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8531 - loss: 0.4111 - val_accuracy: 0.6880 - val_loss: 1.0540
# Epoch 12/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8549 - loss: 0.3896 - val_accuracy: 0.6893 - val_loss: 1.1154
# Epoch 13/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8653 - loss: 0.3722 - val_accuracy: 0.6994 - val_loss: 1.1212
# Epoch 14/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8743 - loss: 0.3468 - val_accuracy: 0.6840 - val_loss: 1.1943
# Epoch 15/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8741 - loss: 0.3467 - val_accuracy: 0.6827 - val_loss: 1.2341
# Epoch 16/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8771 - loss: 0.3293 - val_accuracy: 0.6926 - val_loss: 1.2914
# Epoch 17/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8859 - loss: 0.3056 - val_accuracy: 0.6842 - val_loss: 1.4312
# Epoch 18/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8905 - loss: 0.3036 - val_accuracy: 0.6913 - val_loss: 1.3602
# Epoch 19/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8936 - loss: 0.2875 - val_accuracy: 0.6966 - val_loss: 1.3966
# Epoch 20/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8949 - loss: 0.2820 - val_accuracy: 0.6989 - val_loss: 1.4216
# Epoch 21/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8974 - loss: 0.2704 - val_accuracy: 0.6946 - val_loss: 1.4379
# Epoch 22/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9034 - loss: 0.2615 - val_accuracy: 0.6842 - val_loss: 1.5725
# Epoch 23/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9046 - loss: 0.2539 - val_accuracy: 0.6913 - val_loss: 1.5804
# Epoch 24/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9069 - loss: 0.2545 - val_accuracy: 0.6953 - val_loss: 1.5363
# Epoch 25/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9038 - loss: 0.2532 - val_accuracy: 0.6880 - val_loss: 1.6276
# Epoch 26/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9107 - loss: 0.2362 - val_accuracy: 0.6966 - val_loss: 1.6814
# Epoch 27/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9108 - loss: 0.2352 - val_accuracy: 0.6711 - val_loss: 1.9214
# Epoch 28/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9090 - loss: 0.2419 - val_accuracy: 0.6703 - val_loss: 1.8082
# Epoch 29/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9119 - loss: 0.2324 - val_accuracy: 0.6822 - val_loss: 1.9438
# Epoch 30/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9140 - loss: 0.2282 - val_accuracy: 0.6893 - val_loss: 1.8746
# Epoch 31/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9133 - loss: 0.2311 - val_accuracy: 0.6776 - val_loss: 1.9307
# Epoch 32/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9149 - loss: 0.2222 - val_accuracy: 0.6695 - val_loss: 2.0420
# Epoch 33/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9151 - loss: 0.2207 - val_accuracy: 0.6581 - val_loss: 2.1587
# Epoch 34/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9175 - loss: 0.2147 - val_accuracy: 0.6814 - val_loss: 2.0275
# Epoch 35/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9161 - loss: 0.2181 - val_accuracy: 0.6822 - val_loss: 1.9848
# Epoch 36/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9126 - loss: 0.2286 - val_accuracy: 0.6771 - val_loss: 2.0542
# Epoch 37/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9174 - loss: 0.2130 - val_accuracy: 0.6835 - val_loss: 2.2321
# Epoch 38/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9142 - loss: 0.2173 - val_accuracy: 0.6705 - val_loss: 2.3476
# Epoch 39/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9181 - loss: 0.2129 - val_accuracy: 0.6759 - val_loss: 2.2388
# Epoch 40/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9219 - loss: 0.2026 - val_accuracy: 0.6822 - val_loss: 2.1448
# Epoch 41/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9200 - loss: 0.2066 - val_accuracy: 0.6802 - val_loss: 2.2054
# Epoch 42/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9196 - loss: 0.2134 - val_accuracy: 0.6736 - val_loss: 2.2465
# Epoch 43/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9185 - loss: 0.2109 - val_accuracy: 0.6738 - val_loss: 2.4151
# Epoch 44/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9169 - loss: 0.2138 - val_accuracy: 0.6711 - val_loss: 2.2807
# Epoch 45/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9237 - loss: 0.1983 - val_accuracy: 0.6910 - val_loss: 2.1995
# Epoch 46/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9207 - loss: 0.2033 - val_accuracy: 0.6872 - val_loss: 2.3285
# Epoch 47/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9239 - loss: 0.1999 - val_accuracy: 0.6738 - val_loss: 2.4246
# Epoch 48/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9227 - loss: 0.1988 - val_accuracy: 0.6850 - val_loss: 2.2825
# Epoch 49/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9203 - loss: 0.2006 - val_accuracy: 0.6736 - val_loss: 2.4928
# Epoch 50/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9197 - loss: 0.2048 - val_accuracy: 0.6698 - val_loss: 2.5244
# Epoch 51/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9252 - loss: 0.1907 - val_accuracy: 0.6789 - val_loss: 2.4308
# Epoch 52/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9218 - loss: 0.2009 - val_accuracy: 0.6640 - val_loss: 2.7100
# Epoch 53/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9180 - loss: 0.2068 - val_accuracy: 0.6675 - val_loss: 2.8010
# Epoch 54/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9230 - loss: 0.1918 - val_accuracy: 0.6779 - val_loss: 2.5617
# Epoch 55/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9198 - loss: 0.2018 - val_accuracy: 0.6711 - val_loss: 2.7138
# Epoch 56/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9213 - loss: 0.1951 - val_accuracy: 0.6751 - val_loss: 2.6544
# Epoch 57/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9200 - loss: 0.2030 - val_accuracy: 0.6769 - val_loss: 2.3890
# Epoch 58/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9238 - loss: 0.1920 - val_accuracy: 0.6797 - val_loss: 2.5612
# Epoch 59/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9229 - loss: 0.1875 - val_accuracy: 0.6751 - val_loss: 2.7765
# Epoch 60/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9260 - loss: 0.1851 - val_accuracy: 0.6776 - val_loss: 2.5679
# Epoch 61/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9262 - loss: 0.1845 - val_accuracy: 0.6564 - val_loss: 2.7948
# Epoch 62/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9180 - loss: 0.2093 - val_accuracy: 0.6779 - val_loss: 2.5162
# Epoch 63/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9237 - loss: 0.1883 - val_accuracy: 0.6809 - val_loss: 2.6737
# Epoch 64/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9265 - loss: 0.1840 - val_accuracy: 0.6594 - val_loss: 2.9202
# Epoch 65/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9222 - loss: 0.1950 - val_accuracy: 0.6789 - val_loss: 2.7770
# Epoch 66/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9269 - loss: 0.1785 - val_accuracy: 0.6647 - val_loss: 2.8594
# Epoch 67/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9221 - loss: 0.1947 - val_accuracy: 0.6680 - val_loss: 2.6080
# Epoch 68/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9208 - loss: 0.1978 - val_accuracy: 0.6812 - val_loss: 2.6529
# Epoch 69/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9253 - loss: 0.1815 - val_accuracy: 0.6779 - val_loss: 2.6465
# Epoch 70/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9261 - loss: 0.1801 - val_accuracy: 0.6741 - val_loss: 2.7067
# Epoch 71/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9213 - loss: 0.1996 - val_accuracy: 0.6837 - val_loss: 2.7839
# Epoch 72/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9272 - loss: 0.1771 - val_accuracy: 0.6746 - val_loss: 2.8701
# Epoch 73/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9260 - loss: 0.1787 - val_accuracy: 0.6465 - val_loss: 3.0945
# Epoch 74/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9184 - loss: 0.2093 - val_accuracy: 0.6746 - val_loss: 2.7678
# Epoch 75/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9218 - loss: 0.1993 - val_accuracy: 0.6690 - val_loss: 2.7528
# Epoch 76/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9269 - loss: 0.1870 - val_accuracy: 0.6786 - val_loss: 2.8501
# Epoch 77/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9247 - loss: 0.1797 - val_accuracy: 0.6746 - val_loss: 2.7915
# Epoch 78/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9249 - loss: 0.1801 - val_accuracy: 0.6812 - val_loss: 2.9179
# Epoch 79/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9249 - loss: 0.1805 - val_accuracy: 0.6754 - val_loss: 2.9681
# Epoch 80/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9273 - loss: 0.1750 - val_accuracy: 0.6842 - val_loss: 2.9345
# Epoch 81/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9198 - loss: 0.2022 - val_accuracy: 0.6670 - val_loss: 2.9031
# Epoch 82/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9228 - loss: 0.1925 - val_accuracy: 0.6703 - val_loss: 2.8499
# Epoch 83/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9271 - loss: 0.1809 - val_accuracy: 0.6698 - val_loss: 2.9447
# Epoch 84/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9252 - loss: 0.1881 - val_accuracy: 0.6645 - val_loss: 3.0911
# Epoch 85/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9256 - loss: 0.1824 - val_accuracy: 0.6698 - val_loss: 3.1089
# Epoch 86/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9288 - loss: 0.1734 - val_accuracy: 0.6741 - val_loss: 2.9304
# Epoch 87/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9202 - loss: 0.2002 - val_accuracy: 0.6516 - val_loss: 3.1159
# Epoch 88/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9234 - loss: 0.1931 - val_accuracy: 0.6809 - val_loss: 2.8920
# Epoch 89/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9288 - loss: 0.1737 - val_accuracy: 0.6905 - val_loss: 2.9120
# Epoch 90/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9287 - loss: 0.1739 - val_accuracy: 0.6587 - val_loss: 3.1213
# Epoch 91/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9267 - loss: 0.1789 - val_accuracy: 0.6685 - val_loss: 3.2332
# Epoch 92/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9255 - loss: 0.1876 - val_accuracy: 0.6594 - val_loss: 3.0759
# Epoch 93/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9254 - loss: 0.1857 - val_accuracy: 0.6627 - val_loss: 3.2151
# Epoch 94/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9268 - loss: 0.1755 - val_accuracy: 0.6776 - val_loss: 3.0619
# Epoch 95/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9231 - loss: 0.1906 - val_accuracy: 0.6723 - val_loss: 3.1873
# Epoch 96/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9297 - loss: 0.1717 - val_accuracy: 0.6743 - val_loss: 3.1770
# Epoch 97/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9269 - loss: 0.1812 - val_accuracy: 0.6817 - val_loss: 3.0746
# Epoch 98/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9295 - loss: 0.1716 - val_accuracy: 0.6723 - val_loss: 3.0578
# Epoch 99/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9211 - loss: 0.2025 - val_accuracy: 0.6579 - val_loss: 3.4965
# Epoch 100/100
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9242 - loss: 0.1931 - val_accuracy: 0.6726 - val_loss: 3.1379

# %%
# Define a list of colors for plotting
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# Print mean and standard deviation of MSE scores
print("MSE")
print(f"Mean: {np.mean(scores).round(4)}\nStd:  {np.std(scores).round(4)}")

# Create a figure for MSE visualization
plt.figure(figsize=(15,6))

# Plot MSE for each fold
for fold_idx in range(num_folds):
    plt.plot(histories[fold_idx]['accuracy'][:-patience], color=colors[fold_idx], label=f'Fold N°{fold_idx+1}')
    plt.title('Accuracy')
    plt.legend(loc='upper right')
    plt.grid(alpha=.3)

# Show the plot
plt.show()
# Out:
# MSE
# Mean: 0.6699
# Std:  0.0086

# %%
# Calculate the average best epoch
avg_epochs = int(np.mean(best_epochs))
print(f"Best average epoch: {avg_epochs}")
# Out:
# Best average epoch: 90

# %%
# Build the final model using the calculated average best epoch
final_model = build_model(input_shape)

# Train the final model on the combined training and validation data
final_history = final_model.fit(
    x = X_train_val,
    y = y_train_val,
    batch_size = batch_size,
    epochs = avg_epochs
).history

# Save the trained model to a file with the accuracy included in the filename
model_filename = 'cell_v2.keras'
final_model.save(model_filename)

# Delete the model to free up resources
del final_model
# Out:
# Epoch 1/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3547 - loss: 1.6869
# Epoch 2/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6143 - loss: 1.0293
# Epoch 3/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6790 - loss: 0.8651
# Epoch 4/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7081 - loss: 0.7845
# Epoch 5/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7336 - loss: 0.7161
# Epoch 6/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7566 - loss: 0.6669
# Epoch 7/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7774 - loss: 0.6145
# Epoch 8/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7940 - loss: 0.5764
# Epoch 9/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8055 - loss: 0.5394
# Epoch 10/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8217 - loss: 0.5019
# Epoch 11/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8294 - loss: 0.4799
# Epoch 12/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8406 - loss: 0.4463
# Epoch 13/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8471 - loss: 0.4248
# Epoch 14/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8533 - loss: 0.4121
# Epoch 15/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8587 - loss: 0.3928
# Epoch 16/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8650 - loss: 0.3767
# Epoch 17/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8718 - loss: 0.3562
# Epoch 18/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8753 - loss: 0.3440
# Epoch 19/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8813 - loss: 0.3287
# Epoch 20/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8844 - loss: 0.3182
# Epoch 21/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8857 - loss: 0.3100
# Epoch 22/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8920 - loss: 0.2988
# Epoch 23/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8905 - loss: 0.2949
# Epoch 24/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8918 - loss: 0.2906
# Epoch 25/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8943 - loss: 0.2877
# Epoch 26/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8955 - loss: 0.2808
# Epoch 27/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8948 - loss: 0.2817
# Epoch 28/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8959 - loss: 0.2800
# Epoch 29/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8967 - loss: 0.2743
# Epoch 30/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9022 - loss: 0.2589
# Epoch 31/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9051 - loss: 0.2559
# Epoch 32/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9044 - loss: 0.2522
# Epoch 33/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9054 - loss: 0.2445
# Epoch 34/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9066 - loss: 0.2440
# Epoch 35/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9089 - loss: 0.2399
# Epoch 36/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9118 - loss: 0.2367
# Epoch 37/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9125 - loss: 0.2289
# Epoch 38/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9122 - loss: 0.2279
# Epoch 39/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9143 - loss: 0.2232
# Epoch 40/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9094 - loss: 0.2321
# Epoch 41/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9121 - loss: 0.2296
# Epoch 42/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9148 - loss: 0.2225
# Epoch 43/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9150 - loss: 0.2210
# Epoch 44/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9150 - loss: 0.2218
# Epoch 45/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9145 - loss: 0.2237
# Epoch 46/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9171 - loss: 0.2142
# Epoch 47/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9190 - loss: 0.2088
# Epoch 48/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9186 - loss: 0.2114
# Epoch 49/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9198 - loss: 0.2110
# Epoch 50/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9160 - loss: 0.2193
# Epoch 51/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9166 - loss: 0.2121
# Epoch 52/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9181 - loss: 0.2112
# Epoch 53/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9205 - loss: 0.2033
# Epoch 54/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9186 - loss: 0.2122
# Epoch 55/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9167 - loss: 0.2105
# Epoch 56/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9232 - loss: 0.1964
# Epoch 57/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9230 - loss: 0.1986
# Epoch 58/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9232 - loss: 0.1952
# Epoch 59/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9253 - loss: 0.1934
# Epoch 60/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9246 - loss: 0.1935
# Epoch 61/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9192 - loss: 0.2080
# Epoch 62/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9232 - loss: 0.2001
# Epoch 63/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9256 - loss: 0.1935
# Epoch 64/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9281 - loss: 0.1812
# Epoch 65/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9237 - loss: 0.1929
# Epoch 66/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9259 - loss: 0.1879
# Epoch 67/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9259 - loss: 0.1879
# Epoch 68/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9236 - loss: 0.1920
# Epoch 69/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9225 - loss: 0.2021
# Epoch 70/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9248 - loss: 0.1871
# Epoch 71/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9219 - loss: 0.2044
# Epoch 72/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9272 - loss: 0.1796
# Epoch 73/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9282 - loss: 0.1791
# Epoch 74/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9259 - loss: 0.1895
# Epoch 75/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9247 - loss: 0.1881
# Epoch 76/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9266 - loss: 0.1872
# Epoch 77/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9274 - loss: 0.1847
# Epoch 78/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9292 - loss: 0.1773
# Epoch 79/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9295 - loss: 0.1801
# Epoch 80/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9293 - loss: 0.1763
# Epoch 81/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9303 - loss: 0.1738
# Epoch 82/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9260 - loss: 0.1939
# Epoch 83/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9241 - loss: 0.1905
# Epoch 84/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9297 - loss: 0.1749
# Epoch 85/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9322 - loss: 0.1687
# Epoch 86/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9316 - loss: 0.1704
# Epoch 87/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9275 - loss: 0.1850
# Epoch 88/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9236 - loss: 0.1968
# Epoch 89/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9306 - loss: 0.1722
# Epoch 90/90
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9306 - loss: 0.1777

# %% [markdown]
# ## 🕹️ Use the Model - Make Inference

# %%
# Load the saved model
model = tfk.models.load_model('cell_v2.keras')

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ Input (InputLayer)          │ (None, 96, 96, 3)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1 (Conv2D)              │ (None, 96, 96, 32)    │        896 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act1 (Activation)           │ (None, 96, 96, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp1 (MaxPooling2D)          │ (None, 48, 48, 32)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2 (Conv2D)              │ (None, 48, 48, 64)    │     18,496 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ act2 (Activation)           │ (None, 48, 48, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ mp2 (MaxPooling2D)          │ (None, 24, 24, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten (Flatten)           │ (None, 36864)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 8)             │    294,920 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ softmax (Activation)        │ (None, 8)             │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 942,938 (3.60 MB)
#  Trainable params: 314,312 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 628,626 (2.40 MB)

# %%
# Predict class probabilities and get predicted classes
test_predictions = model.predict(X_test, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)

# Extract ground truth classes
test_gt = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_gt, test_predictions, average='weighted')
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_gt, test_predictions, average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_gt, test_predictions, average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(test_gt, test_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=list(labels_dict.values()), yticklabels=list(labels_dict.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 0.6904
# Precision score over the test set: 0.7044
# Recall score over the test set: 0.6904
# F1 score over the test set: 0.6884

# %% [markdown]
# ## 📊 Prepare Your Submission
#
#
#
#
#
#
#
# To prepare your submission, create a `.zip` file that includes all the necessary code to run your model. It **must** include a `model.py` file with the following class:
#
#
#
#
#
#
#
# ```python
#
#
#
# # file: model.py
#
#
#
# class Model:
#
#
#
#     def __init__(self):
#
#
#
#         """Initialize the internal state of the model."""
#
#
#
#
#
#
#
#     def predict(self, X):
#
#
#
#         """Return a numpy array with the labels corresponding to the input X."""
#
#
#
# ```
#
#
#
#
#
#
#
# The next cell shows an example implementation of the `model.py` file, which includes loading model weights from the `weights.keras` file and conducting predictions on provided input data. The `.zip` file is created and downloaded in the last notebook cell.
#
#
#
#
#
#
#
# ❗ Feel free to modify the method implementations to better fit your specific requirements, but please ensure that the class name and method interfaces remain unchanged.

# %%
# %%writefile model.py



import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:

    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.
        The following is an example loading the weights of a pre-trained
        model.
        """
        
        self.neural_network = tfk.models.load_model('cell_v2.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime

filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py cell_v2.keras

# from google.colab import files
# files.download(filename)
# Out:
#   adding: model.py (deflated 56%)
#   adding: cell_v2.keras (deflated 19%)
